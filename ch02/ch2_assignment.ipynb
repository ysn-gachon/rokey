# %% [markdown]
# <a href="https://colab.research.google.com/github/ysn-gachon/rokey/blob/main/ch02/ch2_assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Mary's cosmetics")
# Out:
# Mary's cosmetics

# %%
print('신씨가 소리질렀다. "도둑이야"')
# Out:
# 신씨가 소리질렀다. "도둑이야"

# %%
print("안녕하세요.\n만나서\t\t반갑습니다.")
# Out:
# 안녕하세요.
# 만나서		반갑습니다.

# %%
print("first", end = " ");print("second")
# Out:
# first second

# %%
삼성전자 = 50000
수량 = 10
평가금액 = 삼성전자*수량
print("평가금액:",평가금액)
# Out:
# 평가금액: 500000

# %%
a = float("15.79")
print(type(a))
# Out:
# <class 'float'>

# %%
year = "2026"
print("올해", int(year))
print("작년", int(year)-1)
print("재작년", int(year)-2)
# Out:
# 올해 2026
# 작년 2025
# 재작년 2024

# %%
per_month = 48584
month = 36
price = per_month*month

print("에어컨 총 금액:", price)
# Out:
# 에어컨 총 금액: 1749024

# %%
age = int(input("현재 나이를 입력해주세요: "))
after_3years = age + 3

print("3년 후 나이는", after_3years, "살 입니다.")
# Out:
# 현재 나이를 입력해주세요: 24
# 3년 후 나이는 27 살 입니다.

# %% [markdown]
# <a href="https://colab.research.google.com/github/ysn-gachon/rokey/blob/main/ch04/ch04_assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
movie_rank = ["하얼빈", "무파사:라이온킹", "소방관"]
print(movie_rank)
# Out:
# ['하얼빈', '무파사:라이온킹', '소방관']

# %%
movie_rank.append("위키드")
print(movie_rank)
# Out:
# ['하얼빈', '무파사:라이온킹', '소방관', '위키드']

# %%
movie_rank.insert(3, "모아나2")
print(movie_rank)
# Out:
# ['하얼빈', '무파사:라이온킹', '소방관', '모아나2', '위키드']

# %%
movie_rank.remove("소방관")
print(movie_rank)
# Out:
# ['하얼빈', '무파사:라이온킹', '모아나2', '위키드']

# %%
nums = [1, 2, 3, 4, 5]
print(nums[0] + nums[1] + nums[2] + nums[3] + nums[4])
# Out:
# 15

# %%
cook = ["피자", "김밥",

"만두", "양념치킨", "족발", "피자", "김치만두",

"쫄면", "쏘세지", "라면", "팥빙수", "김치전"]

print(len(cook))
# Out:
# 12

# %%
t = ('a', 'b', 'c')
u = list(t)
u[0] = 'A'
t = tuple(u)
print(t)
# Out:
# ('A', 'b', 'c')

# %%
t = ('a', 'b', 'c')
t = ('A', 'b', 'c')
print(t)
# Out:
# ('A', 'b', 'c')

# %%
icecream = {"메로나": 1000, "폴라포": 1200, "빵빠레": 1800}
print(icecream)
# Out:
# {'메로나': 1000, '폴라포': 1200, '빵빠레': 1800}

# %%
icecream["죠스바"] = 1200
icecream["월드콘"] = 1500
print(icecream)
# Out:
# {'메로나': 1000, '폴라포': 1200, '빵빠레': 1800, '죠스바': 1200, '월드콘': 1500}

# %%
icecream["메로나"] = 1300
print(icecream)
# Out:
# {'메로나': 1300, '폴라포': 1200, '빵빠레': 1800, '죠스바': 1200, '월드콘': 1500}

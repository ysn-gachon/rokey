# %% [markdown]
# <a href="https://colab.research.google.com/github/ysn-gachon/rokey/blob/main/ch03/ch03_assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
number = int(input("숫자를 입력하시오: "))

if number >= 0:
  if number % 2 == 0:
    print("짝수")
  else:
    print("홀수")
else:
  print("자연수를 입력해주세요.")
# Out:
# 숫자를 입력하시오: 3
# 홀수

# %%
number = int(input("숫자를 입력하시오: "))
add_20 = number + 20
if add_20 > 255:
  add_20 = 255

print(add_20)
# Out:
# 숫자를 입력하시오: 30
# 50

# %%
number = int(input("숫자를 입력하세요: "))

if number - 20 < 0:
  print(0)
elif number - 20 > 255:
  print(255)
else:
  print(number - 20)
# Out:
# 숫자를 입력하세요: 200
# 180

# %%
time = input("현재시간: ")
if time[-2:] == "00":
  print("정각입니다.")
else:
  print("정각이 아닙니다.")
# Out:
# 현재시간: 02:00
# 정각입니다.

# %%
hour = input("시: ")
minute = input("분: ")
print("현재시간: ", hour, ":", minute, sep="")

if minute == "00":
  print("정각입니다.")
else:
  print("정각이 아닙니다.")
# Out:
# 시: 02
# 분: 00
# 현재시간: 02:00
# 정각입니다.

# %%
score = int(input("점수를 입력하세요: "))
grade = "null"

if 100 >= score >=0:
  if score > 80:
    grade = "A"
  elif score > 60:
    grade = "B"
  elif score > 40:
    grade = "C"
  elif score > 20:
    grade = "D"
  else:
    grade = "E"
  print("grade is", grade)
else:
  print("점수를 잘못 입력하셨습니다.")
# Out:
# 점수를 입력하세요: 83
# grade is A

# %% [markdown]
# <a href="https://colab.research.google.com/github/ysn-gachon/rokey/blob/main/ch01/test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello colab!")
# Out:
# hello colab!

# %%
print("hi")
# Out:
# hi

# %%
print("thanks~")
# Out:
# thanks~

# %% [markdown]
# 텍스트 셀은 컴퓨터가 해석하지 않고 개발자가 참고하는 공간(주석) 입니다.

# %%
#이것도 주석

# %%
'''
 Colab 단축키 사용법
• 실행관련단축키
• Ctrl + Enter = 해당 셀을 실행하고 커서를 해당 셀에위치(결과 값만보기)
• Shift + Enter = 해당 셀을 실행하고 커서를 다음 셀에 위치(다음 코드빠른실행)
• Alt + Enter = 해당 셀을 실행하고커서를다음셀에위치(다음작업공간확보)
• 셀삽입/삭제관련단축키
• Ctrl + M A = 코드 셀 위에 삽입
• Ctrl + M B = 코드 셀 아래 삽입
• Ctrl + M D = 셀 지우기
• Ctrl + M Y = 코드 셀로 변경
• Ctrl + M M = 마크다운(텍스트) 셀로 변경
• Ctrl + M Z = 실행 취소
'''
# Out:
# '\n\uf0a7 Colab 단축키 사용법\n• 실행관련단축키\n• Ctrl + Enter = 해당 셀을 실행하고 커서를 해당 셀에위치(결과 값만보기)\n• Shift + Enter = 해당 셀을 실행하고 커서를 다음 셀에 위치(다음 코드빠른실행)\n• Alt + Enter = 해당 셀을 실행하고커서를다음셀에위치(다음작업공간확보)\n• 셀삽입/삭제관련단축키\n• Ctrl + M A = 코드 셀 위에 삽입\n• Ctrl + M B = 코드 셀 아래 삽입\n• Ctrl + M D = 셀 지우기\n• Ctrl + M Y = 코드 셀로 변경\n• Ctrl + M M = 마크다운(텍스트) 셀로 변경\n• Ctrl + M Z = 실행 취소\n'
